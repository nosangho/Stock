# %% [markdown]
# # 파이썬으로 만드는 투자 전략과 주요 지표

# %%
import pandas as pd
import numpy as np

import FinanceDataReader as fdr
import pandas_datareader as pdr

# %% [markdown]
# ## 1. 바이앤홀드 전략

# %% [markdown]
# ### 데이터 불러오기

# %%
df = pdr.get_data_yahoo('AAPL')
df.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2017-09-27  38.680000  38.384998  38.450001  38.557499  102016800.0  36.593582
# 2017-09-28  38.570000  38.174999  38.472500  38.320000   88022000.0  36.368187
# 2017-09-29  38.532501  38.000000  38.302502  38.529999  105199200.0  36.567482
# 2017-10-02  38.612499  38.180000  38.564999  38.452499   74795200.0  36.493935
# 2017-10-03  38.772499  38.477501  38.502499  38.619999   64921200.0  36.652905

# %% [markdown]
# ### 결측치 확인

# %%
df[df.isin([np.nan, np.inf, -np.inf]).any(1)]
# Out:
# Empty DataFrame
# Columns: [High, Low, Open, Close, Volume, Adj Close]
# Index: []

# %% [markdown]
# ### 데이터 슬라이싱

# %%
# 데이터 슬라이싱
price_df = df.loc[:,["Adj Close"]].copy()
price_df.plot(figsize=(16,9))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
from_date = '2020-12-01'
to_date = '2021-03-02'
price_df.loc[from_date:to_date].plot(figsize=(16,9))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### 일별 수익률 계산
# 바이앤홀드에서 일별 수익률을 계산하는 이유는 매수한 시점부터 매도한 시점까지 보유하게 되는데, 일별 수익률을 누적곱하면 최종적으로 매수한 시점 대비 매도한 시점의 종가 수익률로 계산되기 때문이다.

# %%
price_df['daily_rtn'] = df['Adj Close'].pct_change()
price_df.head(10)
# Out:
#             Adj Close  daily_rtn
# Date
# 2017-09-27  36.593582        NaN
# 2017-09-28  36.368187  -0.006159
# 2017-09-29  36.567482   0.005480
# 2017-10-02  36.493935  -0.002011
# 2017-10-03  36.652905   0.004356
# 2017-10-04  36.415638  -0.006473
# 2017-10-05  36.868813   0.012445
# 2017-10-06  36.847473  -0.000579
# 2017-10-09  36.975578   0.003477
# 2017-10-10  36.989822   0.000385

# %% [markdown]
# ### 일별 수익률의 누적곱 (바이앤홀드전략의 수익률)

# %%
price_df['st_rtn'] = (1+price_df['daily_rtn']).cumprod()
price_df.tail()
# Out:
#              Adj Close  daily_rtn    st_rtn
# Date
# 2022-09-20  156.899994   0.015665  4.287637
# 2022-09-21  153.720001  -0.020268  4.200737
# 2022-09-22  152.740005  -0.006375  4.173956
# 2022-09-23  150.429993  -0.015124  4.110830
# 2022-09-26  150.770004   0.002260  4.120121

# %%
price_df['st_rtn'].plot(figsize=(16,9))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
base_date = '2021-01-05'
tmp_df = price_df.loc[base_date:,['st_rtn']]/price_df.loc[base_date,['st_rtn']]
last_date = tmp_df.index[-1]
print("누적수익 :", tmp_df.loc[last_date,'st_rtn'])
tmp_df.plot(figsize=(16,9))
# Out:
# 누적수익 : 1.1627143714477375
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## 2. 투자 성과 분석 지표

# %% [markdown]
# ### 연평균 복리 수익률 (CAGR)
# 수익률 성과를 분석할땐 산술 평균이 아닌 기하평균을 사용
# 기하평균의 수익률이 복리 성질과 주가 변동이 심한 때에 변동성을 표현함

# %%
CAGR = price_df.loc['2021-04-12','st_rtn']**(252./len(price_df.index))-1
# Out:
# 1.2568078160457792

# %% [markdown]
# ### 최대 낙폭 (MDD)
# 1. 수정종가에 누적최대값(cummax)
# 2. 전체 최대값이 아닌 행(row)별로 진행하면서 누적값 갱신
# 3. 현재 수정 종가에서 누적 최대값 대비 낙폭률을 계산하고 최대하락률(cummin) 계산

# %%
historical_max = price_df['Adj Close'].cummax()
daliy_drawdown = price_df['Adj Close'] / historical_max - 1.0
historical_dd = daliy_drawdown.cummin()
historical_dd.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### 변동성 : 일별 단위 변동성
# 주가 변화 수익률 관점의 변동성
# 변동성은 수익률의 표준편차로 계산 -> 일(daily)단위 변동성을 의미하는데, 일단위의 변동성을 연율화할때 252의 제곱근을 곱해야한다.

# %%
VOL = np.std(price_df['daily_rtn'])*np.sqrt(252.)

# %% [markdown]
# ### 샤프지수 : 사후적 샤프지수
# 위험 대비 수익성 지표
# 실현수익률 산술평균 / 실현수익률 변동성

# %%
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn'])*np.sqrt(252.)

# %% [markdown]
# ### 성과분석 결과

# %%
CAGR = price_df.loc['2021-04-12','st_rtn']**(252./len(price_df.index))-1
Sharpe = np.mean(price_df['daily_rtn']) / np.std(price_df['daily_rtn'])*np.sqrt(252.)
VOL = np.std(price_df['daily_rtn'])*np.sqrt(252.)
MDD = historical_dd.min()
print("CAGR : ", round(CAGR*100, 2), '%')
print("Sharpe : ", round(Sharpe, 2))
print("VOL : ", round(VOL*100, 2), '%')
print("MDD : ", round(-1*MDD*100, 2), '%')
# Out:
# CAGR :  125.68 %
# Sharpe :  2.07
# VOL :  44.3 %
# MDD :  24.38 %
